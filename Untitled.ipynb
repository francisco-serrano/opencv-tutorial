# %% [markdown]
# ## OpenCV Tutorial
# Based on a DZone Article
#
# https://dzone.com/articles/opencv-python-tutorial-computer-vision-using-openc

# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('landscape.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
print('Dimensiones imagen 1: ', img.shape)
print('Dimensiones imagen 2: ', gray.shape)

print(gray[0])
# Out:
# Dimensiones imagen 1:  (151, 220, 3)
# Dimensiones imagen 2:  (151, 220)
# [196 193 189 185 184 185 187 188 194 190 199 211 213 214 211 201 186 188
#  187 185 190 199 199 194 193 198 202 201 196 195 201 207 205 209 214 216
#  213 210 209 209 202 202 203 208 216 222 223 221 223 228 229 224 220 222
#  225 227 218 217 219 224 228 229 226 224 233 228 226 232 240 245 249 253
#  253 251 249 250 251 251 249 247 243 247 249 245 236 227 224 224 218 227
#  225 210 200 197 190 179 190 184 181 183 182 176 173 175 168 171 173 174
#  181 189 191 187 183 183 183 183 183 181 179 177 177 174 173 174 173 171
#  174 180 173 176 180 182 183 183 184 185 183 186 189 189 188 188 189 191
#  198 186 178 179 182 183 184 186 186 179 177 173 165 170 179 180 180 182
#  184 181 177 174 175 176 179 179 178 177 176 176 175 175 172 173 173 171
#  169 168 169 171 171 172 174 175 177 178 178 178 180 184 188 190 189 189
#  189 191 195 198 203 208 211 213 214 213 210 210 210 211 212 213 214 215
#  214 215 215 215]

# %%
plt.imshow(img)
plt.show()
plt.imshow(gray, cmap='gray')
plt.show()
